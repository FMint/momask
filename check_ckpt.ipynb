# %%
#check ckpt
import torch
pretrained_path = './checkpoints/t2m/mtrans_2_2/model/net_best_fid.tar'
ckpt = torch.load(pretrained_path, map_location='cpu')
print(ckpt.keys())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 import torch
#       3 pretrained_path = './checkpoints/t2m/mtrans_2_2/model/net_best_fid.tar'
# ----> 4 ckpt = torch.load(pretrained_path, map_location='cpu')
#       5 print(ckpt.keys())
#
# File f:\fsy\miniconda3\envs\p310\lib\site-packages\torch\serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
# ...

# %%
data=r'f:\fsy\project\momask-codes\checkpoint\finest.tar'
ckpt = torch.load(data, map_location='cpu')
print(ckpt.keys())
print(ckpt['text_encoder'].keys())
print(ckpt['motion_encoder'].keys())
print(ckpt['movement_encoder'].keys())
print(ckpt['opt_text_encoder'].keys())
print(ckpt['opt_motion_encoder'].keys())
print(ckpt['epoch'])
print(ckpt['iter'])
# Out:
# dict_keys(['text_encoder', 'motion_encoder', 'movement_encoder', 'opt_text_encoder', 'opt_motion_encoder', 'epoch', 'iter'])
# odict_keys(['hidden', 'pos_emb.weight', 'pos_emb.bias', 'input_emb.weight', 'input_emb.bias', 'gru.weight_ih_l0', 'gru.weight_hh_l0', 'gru.bias_ih_l0', 'gru.bias_hh_l0', 'gru.weight_ih_l0_reverse', 'gru.weight_hh_l0_reverse', 'gru.bias_ih_l0_reverse', 'gru.bias_hh_l0_reverse', 'output_net.0.weight', 'output_net.0.bias', 'output_net.1.weight', 'output_net.1.bias', 'output_net.3.weight', 'output_net.3.bias'])
# odict_keys(['hidden', 'input_emb.weight', 'input_emb.bias', 'gru.weight_ih_l0', 'gru.weight_hh_l0', 'gru.bias_ih_l0', 'gru.bias_hh_l0', 'gru.weight_ih_l0_reverse', 'gru.weight_hh_l0_reverse', 'gru.bias_ih_l0_reverse', 'gru.bias_hh_l0_reverse', 'output_net.0.weight', 'output_net.0.bias', 'output_net.1.weight', 'output_net.1.bias', 'output_net.3.weight', 'output_net.3.bias'])
# ...
